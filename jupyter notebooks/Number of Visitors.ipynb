# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import csv
import os

# %%
csv_file = ("./data/National Parks Ranked by Total Visitation 1904-2016 and by Year.csv")
Visitation_df= pd.read_csv(csv_file)
Visitation_df
# Out:
#       State Unit Code                             Unit Name  \
# 0        CA      GOGA  Golden Gate National Recreation Area
# 1        NC      BLRI                    Blue Ridge Parkway
# 2        NC      GRSM   Great Smoky Mountains National Park
# 3        VA      GWMP    George Washington Memorial Parkway
# 4        NY      GATE      Gateway National Recreation Area
# ...     ...       ...                                   ...
# 21169    WY      YELL             Yellowstone National Park
# 21170    SD      WICA               Wind Cave National Park
# 21171    OR      CRLA             Crater Lake National Park
# 21172    CA      KICA            Kings Canyon National Park
# 21173    WA      MORA           Mount Rainier National Park
#
#                       Unit Type     Visitors   YearRaw
# 0      National Recreation Area   15,638,777      2016
# 1                       Parkway   15,175,578      2016
# 2                 National Park   11,312,786      2016
# ...

# %%
visitation_renamed_df = Visitation_df.rename(columns = {"State": "State", "Unit Name": "Park Name", 
                                                        "Visitors": "Number of Visitors", "YearRaw": "Year" })
visitation_renamed_df
# Out:
#       State Unit Code                             Park Name  \
# 0        CA      GOGA  Golden Gate National Recreation Area
# 1        NC      BLRI                    Blue Ridge Parkway
# 2        NC      GRSM   Great Smoky Mountains National Park
# 3        VA      GWMP    George Washington Memorial Parkway
# 4        NY      GATE      Gateway National Recreation Area
# ...     ...       ...                                   ...
# 21169    WY      YELL             Yellowstone National Park
# 21170    SD      WICA               Wind Cave National Park
# 21171    OR      CRLA             Crater Lake National Park
# 21172    CA      KICA            Kings Canyon National Park
# 21173    WA      MORA           Mount Rainier National Park
#
#                       Unit Type     Visitors   Year
# 0      National Recreation Area   15,638,777   2016
# 1                       Parkway   15,175,578   2016
# 2                 National Park   11,312,786   2016
# ...

# %%
#Output pandas dataframe into CSV file
output_path = os.path.join('National Parks Ranked by Total Visitation 1904-2016 and by Year.csv')
print(output_path)
visitation_renamed_df.to_csv(output_path)
# Out:
# National Parks Ranked by Total Visitation 1904-2016 and by Year.csv
