# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import csv
import os

# %%
excel_file = ("./data/10 Most Visited National Parks in 2020.xlsx")
MV_df= pd.read_excel(excel_file)
MV_df
# Out:
#    Unnamed: 0                                 Park  Recreational Visits
# 0           1  Great Smoky Mountains National Park                 12.1
# 1           2            Yellowstone National Park                  3.8
# 2           3                   Zion National Park                  3.6
# 3           4         Rocky Mountain National Park                  3.3
# 4           5            Grand Teton National Park                  3.3
# 5           6           Grand Canyon National Park                  2.9
# 6           7        Cuyahoga Valley National Park                  2.8
# 7           8                 Acadia National Park                  2.7
# 8           9                Olympic National Park                  2.5
# 9          10            Joshua Tree National Park                  2.4

# %%
mv_renamed_df = MV_df.rename(columns = {'Unnamed: 0':'Index', 'Name of Parks':'Park',
                                        'Number of Recreational Visits':'Recreational Visits'})
mv_renamed_df
# Out:
#    Index                                 Park  Recreational Visits
# 0      1  Great Smoky Mountains National Park                 12.1
# 1      2            Yellowstone National Park                  3.8
# 2      3                   Zion National Park                  3.6
# 3      4         Rocky Mountain National Park                  3.3
# 4      5            Grand Teton National Park                  3.3
# 5      6           Grand Canyon National Park                  2.9
# 6      7        Cuyahoga Valley National Park                  2.8
# 7      8                 Acadia National Park                  2.7
# 8      9                Olympic National Park                  2.5
# 9     10            Joshua Tree National Park                  2.4

# %%
mv_renamed_df.plot(kind='bar', figsize=(10,8))
plt.title(" Top 10 Most Visited Parks in 2020")
x_axis =["Park"]
#y_axis =["Recreational Visits"]
plt.ylabel("Recreational Visits")
plt.xlabel("Park Names")
plt.plot(x_axis, y_axis, marker="s")
#plt.x_axis["Park Names"]
plt.xticks()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0bf90df12c78> in <module>
#       5 plt.ylabel("Recreational Visits")
#       6 plt.xlabel("Park Names")
# ----> 7 plt.plot(x_axis, y_axis, marker="s")
#       8 #plt.x_axis["Park Names"]
#       9 plt.xticks()
#
# NameError: name 'y_axis' is not defined
