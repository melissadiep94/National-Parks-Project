# %%
import os
import pandas as pd
import numpy
import urllib.request, json
import time
from datetime import date
import requests

#import API key
from config2 import APIKEY

# %%
from natlparks import NatlParks
parks = NatlParks(APIKEY)

# %%
parks_info= parks.parks()
# parks_info

# %%
#Transform into a dataframe with below info...

#print out names of all national parks and their parkCode
#park description
#long and latitude of each park
#address
#link to each park website
#hours of operation
#image of each park
#weatherInfo
#print out activities for each park

# %%
#pd.DataFrame.from_dict(parks_info['data'])

# %%
df = pd.DataFrame(parks_info['data'])

df.head(2)
# Out:
#                                      id                                 url  \
# 0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 1  E4C7784E-66A0-4D44-87D0-3E072F5FEF43  https://www.nps.gov/adam/index.htm
#
#                          fullName parkCode  \
# 0            Acadia National Park     acad
# 1  Adams National Historical Park     adam
#
#                                          description    latitude  \
# 0  Acadia National Park protects the natural beau...   44.409286
# 1  From the sweet little farm at the foot of Penn...  42.2553961
#
#       longitude                            latLong  \
# 0    -68.247501     lat:44.409286, long:-68.247501
# 1  -71.01160356  lat:42.2553961, long:-71.01160356
#
#                                           activities  \
# 0  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 1  [{'id': 'B33DC9B6-0B7D-4322-BAD7-A13A34C584A3'...
#
#                                               topics  ...  \
# 0  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 1  [{'id': 'F3883A66-A7CB-461B-868E-1B5932224B25'...  ...
#
#                                       entrancePasses fees  \
# 0  [{'cost': '55.00', 'description': 'Valid for 1...   []
# 1                                                 []   []
#
#                                       directionsInfo  \
# 0  From Boston take I-95 north to Augusta, Maine,...
# 1  Traveling on U.S. Interstate 93, take exit 7 -...
#
#                                        directionsUrl  \
# 0  http://www.nps.gov/acad/planyourvisit/directio...
# 1  http://www.nps.gov/adam/planyourvisit/directio...
#
#                                       operatingHours  \
# 0  [{'exceptions': [], 'description': 'Acadia Nat...
# 1  [{'exceptions': [{'exceptionHours': {'wednesda...
#
#                                            addresses  \
# 0  [{'postalCode': '04609', 'city': 'Bar Harbor',...
# 1  [{'postalCode': '02169', 'city': 'Quincy', 'st...
#
#                                               images  \
# 0  [{'credit': 'NPS / Kristi Rugg', 'title': 'Aca...
# 1  [{'credit': 'NPS Photo', 'title': 'The John an...
#
#                                          weatherInfo    name  \
# 0  Located on Mount Desert Island in Maine, Acadi...  Acadia
# 1  Be prepared for hot, humid weather. The histor...   Adams
#
#                 designation
# 0             National Park
# 1  National Historical Park
#
# [2 rows x 23 columns]

# %%
# For every 'x' in the activities column, extract the values in the 'name' key and put them in a single list
# Iterates over the rows of the dataframe
df['activity_names'] = df['activities'].apply(lambda x: [k['name'] for k in x])
df['activity_ids'] = df['activities'].apply(lambda x: [k['id'] for k in x])
df['images_url'] = df['images'].apply(lambda x: [k['url'] for k in x])
df['topic_names'] = df['topics'].apply(lambda x: [k['name'] for k in x])
df['topic_ids'] = df['topics'].apply(lambda x: [k['id'] for k in x])
df['addresses_postalCode'] = df['addresses'].apply(lambda x: [k['postalCode'] for k in x])
df['addresses_city'] = df['addresses'].apply(lambda x: [k['city'] for k in x])
df['addresses_stateCode'] = df['addresses'].apply(lambda x: [k['stateCode'] for k in x])
df['addresses_street'] = df['addresses'].apply(lambda x: [k['line1'] for k in x])
df['standardHours'] = df['operatingHours'].apply(lambda x: [k['standardHours'] for k in x])
df['entranceFees_cost'] = df['entranceFees'].apply(lambda x: [k['cost'] for k in x])
df['entranceFees_description'] = df['entranceFees'].apply(lambda x: [k['description'] for k in x])
df.head(2)
# Out:
#                                      id                                 url  \
# 0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 1  E4C7784E-66A0-4D44-87D0-3E072F5FEF43  https://www.nps.gov/adam/index.htm
#
#                          fullName parkCode  \
# 0            Acadia National Park     acad
# 1  Adams National Historical Park     adam
#
#                                          description    latitude  \
# 0  Acadia National Park protects the natural beau...   44.409286
# 1  From the sweet little farm at the foot of Penn...  42.2553961
#
#       longitude                            latLong  \
# 0    -68.247501     lat:44.409286, long:-68.247501
# 1  -71.01160356  lat:42.2553961, long:-71.01160356
#
#                                           activities  \
# 0  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 1  [{'id': 'B33DC9B6-0B7D-4322-BAD7-A13A34C584A3'...
#
#                                               topics  ...  \
# 0  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 1  [{'id': 'F3883A66-A7CB-461B-868E-1B5932224B25'...  ...
#
#                                           images_url  \
# 0  [https://www.nps.gov/common/uploads/structured...
# 1  [https://www.nps.gov/common/uploads/structured...
#
#                                          topic_names  \
# 0  [Arts, Painting, Photography, Poetry and Liter...
# 1             [American Revolution, Women's History]
#
#                                            topic_ids addresses_postalCode  \
# 0  [00F3C3F9-2D67-4802-81AE-CCEA5D3BA370, 05B7868...       [04609, 04609]
# 1  [F3883A66-A7CB-461B-868E-1B5932224B25, 7DA81DA...       [02169, 02169]
#
#              addresses_city addresses_stateCode  \
# 0  [Bar Harbor, Bar Harbor]            [ME, ME]
# 1          [Quincy, Quincy]            [MA, MA]
#
#                           addresses_street  \
# 0     [25 Visitor Center Road, PO Box 177]
# 1  [1250 Hancock Street, 135 Adams Street]
#
#                                        standardHours      entranceFees_cost  \
# 0  [{'wednesday': 'All Day', 'monday': 'All Day',...  [30.00, 25.00, 15.00]
# 1  [{'wednesday': '10:00AM - 4:00PM', 'monday': '...                [15.00]
#
#                             entranceFees_description
# 0  [Admits private, non-commercial vehicle (15 pa...
# 1  [2021 Update: Entrance Fees are waived for 202...
#
# [2 rows x 35 columns]

# %%
#Drop columns not needed

df_clean= df.drop(columns=['id', 'activities', 'topics', 'contacts', 'entranceFees', 'entrancePasses' , 'fees', 'operatingHours', 'addresses', 'images', 'name'])

# %%
#Re-order columns

df_clean = df_clean.reindex(columns=
                                     ['parkCode',
                                     'fullName',
                                     'url',
                                     'designation',
                                     'description',
                                     'latitude',
                                     'longitude',
                                     'latLong',
                                     'states',
                                     'directionsInfo',
                                     'directionsUrl',
                                     'weatherInfo',
                                     'activity_names',
                                     'activity_ids',
                                     'images_url',
                                     'topic_names',
                                     'topic_ids',
                                     'addresses_postalCode',
                                     'addresses_city',
                                     'addresses_stateCode',
                                     'addresses_street',
                                     'standardHours',
                                     'entranceFees_cost',
                                     'entranceFees_description']  
                                     
                                     
                                     )

df_clean.head(2)
# Out:
#   parkCode                        fullName  \
# 0     acad            Acadia National Park
# 1     adam  Adams National Historical Park
#
#                                   url               designation  \
# 0  https://www.nps.gov/acad/index.htm             National Park
# 1  https://www.nps.gov/adam/index.htm  National Historical Park
#
#                                          description    latitude  \
# 0  Acadia National Park protects the natural beau...   44.409286
# 1  From the sweet little farm at the foot of Penn...  42.2553961
#
#       longitude                            latLong states  \
# 0    -68.247501     lat:44.409286, long:-68.247501     ME
# 1  -71.01160356  lat:42.2553961, long:-71.01160356     MA
#
#                                       directionsInfo  ...  \
# 0  From Boston take I-95 north to Augusta, Maine,...  ...
# 1  Traveling on U.S. Interstate 93, take exit 7 -...  ...
#
#                                           images_url  \
# 0  [https://www.nps.gov/common/uploads/structured...
# 1  [https://www.nps.gov/common/uploads/structured...
#
#                                          topic_names  \
# 0  [Arts, Painting, Photography, Poetry and Liter...
# 1             [American Revolution, Women's History]
#
#                                            topic_ids addresses_postalCode  \
# 0  [00F3C3F9-2D67-4802-81AE-CCEA5D3BA370, 05B7868...       [04609, 04609]
# 1  [F3883A66-A7CB-461B-868E-1B5932224B25, 7DA81DA...       [02169, 02169]
#
#              addresses_city addresses_stateCode  \
# 0  [Bar Harbor, Bar Harbor]            [ME, ME]
# 1          [Quincy, Quincy]            [MA, MA]
#
#                           addresses_street  \
# 0     [25 Visitor Center Road, PO Box 177]
# 1  [1250 Hancock Street, 135 Adams Street]
#
#                                        standardHours      entranceFees_cost  \
# 0  [{'wednesday': 'All Day', 'monday': 'All Day',...  [30.00, 25.00, 15.00]
# 1  [{'wednesday': '10:00AM - 4:00PM', 'monday': '...                [15.00]
#
#                             entranceFees_description
# 0  [Admits private, non-commercial vehicle (15 pa...
# 1  [2021 Update: Entrance Fees are waived for 202...
#
# [2 rows x 24 columns]

# %%
list(df_clean.columns.values)
# Out:
# ['parkCode',
#  'fullName',
#  'url',
#  'designation',
#  'description',
#  'latitude',
#  'longitude',
#  'latLong',
#  'states',
#  'directionsInfo',
#  'directionsUrl',
#  'weatherInfo',
#  'activity_names',
#  'activity_ids',
#  'images_url',
#  'topic_names',
#  'topic_ids',
#  'addresses_postalCode',
#  'addresses_city',
#  'addresses_stateCode',
#  'addresses_street',
#  'standardHours',
#  'entranceFees_cost',
#  'entranceFees_description']

# %%
#Output pandas dataframe into CSV file
output_path = os.path.join('../CSV file/national_park_data.csv')
print(output_path)
df_clean.to_csv(output_path)
# Out:
# ../CSV file/national_park_data.csv
